# %%
import os
import emoji
import re
import string
import spacy
import pandas as pd
from transformers import pipeline

# %%
# Get the absolute path to the data directory
abs_dir = os.path.abspath(os.path.dirname(os.getcwd()))

# %%
df = pd.read_csv(os.path.join(abs_dir, 'data/merged_dataset.csv'))

# %%
pd.set_option('display.max_colwidth', None)

df.sample(10)
# Out:
#                                                                                                                                                                                                                                                             review_text  \
# 3459                                                                                                                                                                                                                              Very nice, but requires paid network.
# 5401  The app does not work well from abroad, there have been continuous upgrades and updates that are very interruptive and non-responsive. Staff do not have the technical capabilities to support whereas the support number and online support are never available.
# 1813                                                                                  This app is the best, easy and more clear to use including its features to understand so i liked it 100% because the app made the life of customers easy. Thanks cbe and the app.
# 1351                                                                Its good but we need an option of choosing a specific period to get a historique of transactions. For example when i want to check my previous transactions i only get few transactions. Thank you.
# 285                                                                                                                                                                                                                            the worst app in the market only good ui
# 5331                                                                                                                                                                                                                                                  An excellent app.
# 414                                                                                                                                                                                                                                             Always one step forward
# 4019                                                                                                                                                                                                                                                           Nice app
# 3356                                                                                                                                                                                                                                                                  👍
# 4176                                                                                                                                                                                                            The best way to get rid of my life thank you so much ❤️
#
#       rating  upvote        date                    bank_name       source
# 3459       3       3  2024-03-04  Commercial Bank of Ethiopia  Google Play
# 5401       1      75  2024-02-12            Bank of Abyssinia  Google Play
# 1813       5     705  2024-12-27  Commercial Bank of Ethiopia  Google Play
# 1351       2      37  2025-01-30  Commercial Bank of Ethiopia  Google Play
# 285        1       2  2025-03-22                  Dashen Bank  Google Play
# 5331       5       1  2024-03-01            Bank of Abyssinia  Google Play
# 414        5       3  2025-01-15                  Dashen Bank  Google Play
# 4019       5       1  2024-01-17  Commercial Bank of Ethiopia  Google Play
# 3356       5       1  2024-03-13  Commercial Bank of Ethiopia  Google Play
# 4176       5       1  2023-12-22  Commercial Bank of Ethiopia  Google Play

# %%
# check types 
df.dtypes
# Out:
# review_text    object
# rating          int64
# upvote          int64
# date           object
# bank_name      object
# source         object
# dtype: object

# %%
# change date format from object to 'YYYY-MM-DD' format
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df.dtypes
# Out:
# review_text            object
# rating                  int64
# upvote                  int64
# date           datetime64[ns]
# bank_name              object
# source                 object
# dtype: object

# %%
df.describe()
# Out:
#             rating       upvote                           date
# count  5493.000000  5493.000000                           5493
# mean      3.940834     8.674495  2024-08-31 16:32:14.680502272
# min       1.000000     0.000000            2023-11-06 00:00:00
# 25%       3.000000     0.000000            2024-03-25 00:00:00
# 50%       5.000000     1.000000            2024-08-27 00:00:00
# 75%       5.000000     2.000000            2025-01-31 00:00:00
# max       5.000000  3025.000000            2025-06-07 00:00:00
# std       1.596825    78.129692                            NaN

# %%
# check for null values in the DataFrame
df.isnull().sum()
# Out:
# review_text    0
# rating         0
# upvote         0
# date           0
# bank_name      0
# source         0
# dtype: int64

# %%
# Check for duplicated data
dublicated_data = df.duplicated(subset=['review_text', 'rating']).sum()
print(f'data duplicated: {dublicated_data}')
df[df.duplicated()]
# Out:
# data duplicated: 1306
#                           review_text  rating  upvote       date  \
# 214   best mobile banking application       5       2 2025-04-21
# 464                              good       5       0 2025-06-04
# 523                              good       5       0 2025-05-23
# 525                              good       5       0 2025-05-23
# 535                                ok       5       0 2025-05-22
# ...                               ...     ...     ...        ...
# 4131                             Good       5       1 2023-12-30
# 4480                             good       4       0 2025-04-30
# 5093                             best       5       1 2024-05-02
# 5213                             Good       5       1 2024-04-22
# 5382                         Best app       5       1 2024-02-16
#
#                         bank_name       source
# 214                   Dashen Bank  Google Play
# 464   Commercial Bank of Ethiopia  Google Play
# 523   Commercial Bank of Ethiopia  Google Play
# 525   Commercial Bank of Ethiopia  Google Play
# 535   Commercial Bank of Ethiopia  Google Play
# ...                           ...          ...
# 4131  Commercial Bank of Ethiopia  Google Play
# 4480            Bank of Abyssinia  Google Play
# 5093            Bank of Abyssinia  Google Play
# 5213            Bank of Abyssinia  Google Play
# 5382            Bank of Abyssinia  Google Play
#
# [86 rows x 6 columns]

# %%
# remove duplicated data
df.drop_duplicates(subset=['review_text', 'rating'], inplace=True)

# %%
df.shape
# Out:
# (4187, 6)

# %%
# How to transfor emojis to text as a preprocessing step
def preprocess_text(text):
    # Convert emojis to text
    text = emoji.demojize(text, language='en')
    
    # Convert to lowercase
    text = text.lower()
    
    # Remove punctuation (excluding emoji placeholders like :smile:)
    text = re.sub(f"[{re.escape(string.punctuation)}]", " ", text)
    
    # Remove multiple spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
df['review_text'] = df['review_text'].apply(preprocess_text)

# %%
# Load the sentiment analysis pipeline
sentiment_pipeline = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

sentiment_results = df['review_text'].astype(str).apply(lambda x: sentiment_pipeline(x)[0])

df[['sentiment_label', 'sentiment_score']] = df['review_text'].astype(str).apply(
    lambda x: pd.Series({
        'sentiment_label': sentiment_pipeline(x)[0]['label'],
        'sentiment_score': sentiment_pipeline(x)[0]['score']
    })
)
# Out:
# Device set to use cpu

# %%
df
# Out:
#                                                                                                                                                          review_text  \
# 0     i like this mobile banking app very much overall user interface and navigation is awesome but it lacks instant response when someone deposit or withdraw money
# 1                                                                                                                                                               love
# 2                                                                                                                                                               መቸሸጠ
# 3                                                                                                                                                                wow
# 4                                                                                                                                                              gadaa
# ...                                                                                                                                                              ...
# 5485                                                                                                                                                        nice one
# 5486                                                                                                                                በጣም ደስ የሚል ለውጥ አናመሰግናለን ethiopia
# 5487                                                                                                             best application thumbs up thank you abyssinia bank
# 5490                                                                                            absolutely it s fantastic apps this new apps it s fast and good apps
# 5491                                                                                                                      the best app next to tele birr in ethiopia
#
#       rating  upvote       date          bank_name       source  \
# 0          2       0 2025-06-07        Dashen Bank  Google Play
# 1          3       0 2025-06-06        Dashen Bank  Google Play
# 2          5       0 2025-06-03        Dashen Bank  Google Play
# 3          5       0 2025-06-03        Dashen Bank  Google Play
# 4          5       0 2025-06-01        Dashen Bank  Google Play
# ...      ...     ...        ...                ...          ...
# 5485       5       5 2024-01-14  Bank of Abyssinia  Google Play
# 5486       5      10 2024-01-14  Bank of Abyssinia  Google Play
# 5487       5      12 2024-01-12  Bank of Abyssinia  Google Play
# 5490       5      27 2024-01-11  Bank of Abyssinia  Google Play
# 5491       5      48 2024-01-10  Bank of Abyssinia  Google Play
#
#      sentiment_label  sentiment_score
# 0           NEGATIVE         0.998102
# 1           POSITIVE         0.999874
# 2           NEGATIVE         0.697056
# 3           POSITIVE         0.999592
# 4           NEGATIVE         0.721146
# ...              ...              ...
# 5485        POSITIVE         0.999848
# 5486        NEGATIVE         0.547949
# 5487        POSITIVE         0.999482
# 5490        POSITIVE         0.999886
# 5491        POSITIVE         0.998719
#
# [4187 rows x 8 columns]

# %%
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 nlp = spacy.load("en_core_web_sm")
#
# File c:\Users\mesay\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)
#      35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)
#      50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File c:\Users\mesay\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\util.py:484, in load_model(name, vocab, disable, enable, exclude, config)
#     482 if name in OLD_MODEL_SHORTCUTS:
#     483     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 484 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
